# %% [markdown]
# <a href="https://colab.research.google.com/github/salihfurkaan/Akademik-Yayin-ve-Atif-Takip-Sistemi/blob/main/nb/Meta_Synthetic_Data_Llama3_2_(3B).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm==0.8.5.post1
    # !pip install synthetic-data-kit==0.0.3
else:
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # !pip install --no-deps unsloth vllm==0.8.5.post1
    # !pip install synthetic-data-kit==0.0.3

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
else:
    # !pip install --no-deps unsloth vllm==0.8.5.post1

    import sys, re, requests; modules = list(sys.modules.keys())
    for x in modules: sys.modules.pop(x) if "PIL" in x or "google" in x else None
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" "huggingface_hub>=0.34.0" hf_transfer

    # vLLM requirements - vLLM breaks Colab due to reinstalling numpy
    f = requests.get("https://raw.githubusercontent.com/vllm-project/vllm/refs/heads/main/requirements/common.txt").content
    with open("vllm_requirements.txt", "wb") as file:
        file.write(re.sub(rb"(transformers|numpy|xformers)[^\n]{1,}\n", b"", f))
    # !pip install -r vllm_requirements.txt

# %% [markdown]
# ### Unsloth

# %%
from unsloth.dataprep import SyntheticDataKit

generator = SyntheticDataKit.from_pretrained(
    # Choose any model from https://huggingface.co/unsloth
    model_name = "unsloth/Llama-3.2-3B-Instruct",
    max_seq_length = 2048, # Longer sequence lengths will be slower!
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 08-14 10:26:49 [importing.py:53] Triton module has been replaced with a placeholder.
# INFO 08-14 10:26:49 [__init__.py:239] Automatically detected platform cuda.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# config.json:   0%|          | 0.00/890 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# Unsloth: Patching vLLM v1 graph capture
# Unsloth: Patching vLLM v0 graph capture
# Unsloth: Using dtype = torch.float16 for vLLM.
# Unsloth: vLLM loading unsloth/Llama-3.2-3B-Instruct with actual GPU utilization = 89.39%
# Unsloth: Your GPU has CUDA compute capability 7.5 with VRAM = 14.74 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 2048. Num Sequences = 192.
# Unsloth: vLLM's KV Cache can use up to 7.19 GB. Also swap space = 0 GB.
# vLLM STDOUT: INFO 08-14 10:27:32 [__init__.py:239] Automatically detected platform cuda.
# vLLM STDOUT: INFO 08-14 10:27:37 [api_server.py:1043] vLLM API server version 0.8.5.post1
# vLLM STDOUT: INFO 08-14 10:27:37 [api_server.py:1044] args: Namespace(subparser='serve', model_tag='unsloth/Llama-3.2-3B-Instruct', config='', host=None, port=8000, uvicorn_log_level='info', disable_uvicorn_access_log=False, allow_credentials=False, allowed_origins=['*'], allowed_methods=['*'], allowed_headers=['*'], api_key=None, lora_modules=None, prompt_adapters=None, chat_template=None, chat_template_content_format='auto', response_role='assistant', ssl_keyfile=None, ssl_certfile=None, ssl_ca_certs=None, enable_ssl_refresh=False, ssl_cert_reqs=0, root_path=None, middleware=[], return_tokens_as_token_ids=False, disable_frontend_multiprocessing=False, enable_request_id_headers=False, enable_auto_tool_choice=False, tool_call_parser=None, tool_parser_plugin='', model='unsloth/Llama-3.2-3B-Instruct', task='auto', tokenizer=None, hf_config_path=None, skip_tokenizer_init=False, revision=None, code_revision=None, tokenizer_revision=None, tokenizer_mode='auto', trust_remote_code=False, allowed_local_media_path=None, load_format='auto', download_dir=None, model_loader_extra_config={}, use_tqdm_on_load=True, config_format=<ConfigFormat.AUTO: 'auto'>, dtype='float16', max_model_len=2048, guided_decoding_backend='auto', reasoning_parser=None, logits_processor_pattern=None, model_impl='auto', distributed_executor_backend=None, pipeline_parallel_size=1, tensor_parallel_size=1, data_parallel_size=1, enable_expert_parallel=False, max_parallel_loading_workers=None, ray_workers_use_nsight=False, disable_custom_all_reduce=False, block_size=None, gpu_memory_utilization=0.8938626454842437, swap_space=0.0, kv_cache_dtype='auto', num_gpu_blocks_override=None, enable_prefix_caching=True, prefix_caching_hash_algo='builtin', cpu_offload_gb=0, calculate_kv_scales=False, disable_sliding_window=False, use_v2_block_manager=True, seed=0, max_logprobs=0, disable_log_stats=True, quantization=None, rope_scaling=None, rope_theta=None, hf_token=None, hf_overrides=None, enforce_eager=False, max_seq_len_to_capture=8192, tokenizer_pool_size=0, tokenizer_pool_type='ray', tokenizer_pool_extra_config={}, limit_mm_per_prompt={}, mm_processor_kwargs=None, disable_mm_preprocessor_cache=False, enable_lora=None, enable_lora_bias=False, max_loras=1, max_lora_rank=16, lora_extra_vocab_size=256, lora_dtype='auto', long_lora_scaling_factors=None, max_cpu_loras=None, fully_sharded_loras=False, enable_prompt_adapter=None, max_prompt_adapters=1, max_prompt_adapter_token=0, device='auto', speculative_config=None, ignore_patterns=[], served_model_name=None, qlora_adapter_name_or_path=None, show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, disable_async_output_proc=False, max_num_batched_tokens=2048, max_num_seqs=192, max_num_partial_prefills=1, max_long_partial_prefills=1, long_prefill_token_threshold=0, num_lookahead_slots=0, scheduler_delay_factor=0.0, preemption_mode=None, num_scheduler_steps=1, multi_step_stream_outputs=True, scheduling_policy='fcfs', enable_chunked_prefill=None, disable_chunked_mm_input=False, scheduler_cls='vllm.core.scheduler.Scheduler', override_neuron_config=None, override_pooler_config=None, compilation_config={"level":3,"splitting_ops":[]}, kv_transfer_config=None, worker_cls='auto', worker_extension_cls='', generation_config='auto', override_generation_config=None, enable_sleep_mode=False, additional_config=None, enable_reasoning=False, disable_cascade_attn=False, disable_log_requests=False, max_log_len=None, disable_fastapi_docs=False, enable_prompt_tokens_details=False, enable_server_load_tracking=False, dispatch_function=<function ServeSubcommand.cmd at 0x7bd190b48c20>)
# vLLM STDOUT: WARNING 08-14 10:27:38 [config.py:2972] Casting torch.bfloat16 to torch.float16.
# vLLM STDOUT: INFO 08-14 10:27:53 [config.py:717] This model supports multiple tasks: {'score', 'generate', 'reward', 'embed', 'classify'}. Defaulting to 'generate'.
# vLLM STDOUT: WARNING 08-14 10:27:53 [arg_utils.py:1658] Compute Capability < 8.0 is not supported by the V1 Engine. Falling back to V0.
# vLLM STDOUT: INFO 08-14 10:27:53 [api_server.py:246] Started engine process with PID 3338
# vLLM STDOUT: INFO 08-14 10:28:03 [__init__.py:239] Automatically detected platform cuda.
# vLLM STDOUT: INFO 08-14 10:28:09 [llm_engine.py:240] Initializing a V0 LLM engine (v0.8.5.post1) with config: model='unsloth/Llama-3.2-3B-Instruct', speculative_config=None, tokenizer='unsloth/Llama-3.2-3B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=2048, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='auto', reasoning_backend=None), observability_config=ObservabilityConfig(show_hidden_metrics=False, otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/Llama-3.2-3B-Instruct, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":3,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":192}, use_cached_outputs=True,
# vLLM STDOUT: INFO 08-14 10:28:10 [cuda.py:240] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# vLLM STDOUT: INFO 08-14 10:28:10 [cuda.py:289] Using XFormers backend.
# vLLM STDOUT: INFO 08-14 10:28:11 [parallel_state.py:1004] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0
# vLLM STDOUT: INFO 08-14 10:28:11 [model_runner.py:1108] Starting to load model unsloth/Llama-3.2-3B-Instruct...
# vLLM STDOUT: INFO 08-14 10:28:11 [weight_utils.py:265] Using model weights format ['*.safetensors']
# vLLM STDOUT: INFO 08-14 10:30:17 [weight_utils.py:281] Time spent downloading weights for unsloth/Llama-3.2-3B-Instruct: 125.355387 seconds
# vLLM STDOUT: INFO 08-14 10:30:44 [loader.py:458] Loading weights took 26.85 seconds
# vLLM STDOUT: INFO 08-14 10:30:44 [model_runner.py:1140] Model loading took 6.0160 GiB and 153.009934 seconds
# vLLM STDOUT: INFO 08-14 10:30:56 [backends.py:420] Using cache directory: /root/.cache/vllm/torch_compile_cache/179d9bccf3/rank_0_0 for vLLM's torch.compile
# vLLM STDOUT: INFO 08-14 10:30:56 [backends.py:430] Dynamo bytecode transform time: 10.98 s
# vLLM STDOUT: INFO 08-14 10:31:36 [backends.py:136] Cache the graph of shape None for later use
# vLLM STDOUT: INFO 08-14 10:31:36 [backends.py:148] Compiling a graph for general shape takes 35.86 s
# vLLM STDOUT: INFO 08-14 10:31:37 [monitor.py:33] torch.compile takes 46.84 s in total
# vLLM STDOUT: INFO 08-14 10:31:40 [worker.py:287] Memory profiling takes 54.72 seconds
# vLLM STDOUT: INFO 08-14 10:31:40 [worker.py:287] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.89) = 13.18GiB
# vLLM STDOUT: INFO 08-14 10:31:40 [worker.py:287] model weights take 6.02GiB; non_torch_memory takes 0.05GiB; PyTorch activation peak memory takes 0.90GiB; the rest of the memory reserved for KV Cache is 6.22GiB.
# vLLM STDOUT: INFO 08-14 10:31:40 [executor_base.py:112] # cuda blocks: 3637, # CPU blocks: 0
# vLLM STDOUT: INFO 08-14 10:31:40 [executor_base.py:117] Maximum concurrency for 2048 tokens per request: 28.41x
# vLLM STDOUT: INFO 08-14 10:31:40 [model_runner.py:1450] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# vLLM STDOUT: INFO 08-14 10:32:19 [model_runner.py:1592] Graph capturing finished in 38 secs, took 0.17 GiB
# vLLM STDOUT: INFO 08-14 10:32:19 [llm_engine.py:437] init engine (profile, create kv cache, warmup model) took 94.17 seconds
# vLLM STDOUT: WARNING 08-14 10:32:19 [config.py:1239] Default sampling parameters have been overridden by the model's Hugging Face generation config recommended from the model creator. If this is not intended, please relaunch vLLM instance with `--generation-config vllm`.
# vLLM STDOUT: INFO 08-14 10:32:19 [serving_chat.py:118] Using default chat sampling params from model: {'temperature': 0.6, 'top_p': 0.9}
# vLLM STDOUT: INFO 08-14 10:32:19 [serving_completion.py:61] Using default completion sampling params from model: {'temperature': 0.6, 'top_p': 0.9}
# vLLM STDOUT: INFO 08-14 10:32:19 [api_server.py:1090] Starting vLLM API server on http://0.0.0.0:8000
#
# --- vLLM Server Ready (Detected: 'Starting vLLM API server on') ---

# %% [markdown]
# ## Generate QA Pairs + Auto clean data
# We now use synthetic data kit for question answer pair generation:

# %%
generator.prepare_qa_generation(
    output_folder = "dataset", # Output location of synthetic data
    temperature = 0.7, # Higher temp makes more diverse datases
    top_p = 0.95,
    overlap = 64, # Overlap portion during chunking
    max_generation_tokens = 512, # Can increase for longer QA pairs
)

# %% [markdown]
# Check if it succeeded:

# %%
# !synthetic-data-kit system-check
# Out:
#  VLLM server is running at http://localhost:8000/v1
# Available models: {'object': 'list', 'data': [{'id':
# 'unsloth/Llama-3.2-3B-Instruct', 'object': 'model', 'created': 1755171410,
# 'owned_by': 'vllm', 'root': 'unsloth/Llama-3.2-3B-Instruct', 'parent': None,
# 'max_model_len': 2048, 'permission': [{'id':
# 'modelperm-98f1021e55554e1eb5c3b40b6809705f', 'object': 'model_permission',
# 'created': 1755171410, 'allow_create_engine': False, 'allow_sampling': True,
# 'allow_logprobs': True, 'allow_search_indices': False, 'allow_view': True,
# 'allow_fine_tuning': False, 'organization': '*', 'group': None, 'is_blocking':
# False}]}]}
# ⠋ Checking VLLM server at http://localhost:8000/v1...

# %% [markdown]
# ## Document Parsing (PDF, CSV, HTML etc.)
# Now, let's take the Byte Latent Transformer: Patches Scale Better Than Tokens research paper found at https://arxiv.org/abs/2412.09871 and covert it to Q&A pairs in order to finetune Llama 3.2!

# %%
import glob
import os

pdf_files = glob.glob("pdfs/*.pdf")

if not pdf_files:
    print("No PDF files found in pdfs/")
else:
    print(f"Found {len(pdf_files)} PDF files. Ingesting...")
    for pdf_file in pdf_files:
        print(f"Ingesting {pdf_file}...")
        # !synthetic-data-kit \
            -c synthetic_data_kit_config.yaml \
            ingest "{pdf_file}"

# !ls -l data/output/

# Truncate document
filenames = generator.chunk_data("dataset/output/*.txt")
print(len(filenames), filenames[:3])
# Out:
# Found 83 PDF files. Ingesting...
# Ingesting pdfs/master_int_kkabul.pdf...
# ⠧ Processing pdfs/master_int_kkabul.pdf...
#  Text successfully extracted to dataset/output/master_int_kkabul.txt
# Ingesting pdfs/obs_yetki_tanimlama.pdf...
# ⠸ Processing pdfs/obs_yetki_tanimlama.pdf...
#  Text successfully extracted to dataset/output/obs_yetki_tanimlama.txt
# Ingesting pdfs/turkce_ogretimi_uygulama.pdf...
# ⠴ Processing pdfs/turkce_ogretimi_uygulama.pdf...
#  Text successfully extracted to dataset/output/turkce_ogretimi_uygulama.txt
# Ingesting pdfs/BİLİMSEL ARAŞTIRMA VE YAYIN ETİK KURULU YÖNERGESİ.pdf...
# ⠸ Processing pdfs/BİLİMSEL ARAŞTIRMA VE YAYIN ETİK KURULU YÖNERGESİ.pdf...
#  Text successfully extracted to dataset/output/BİLİMSEL ARAŞTIRMA VE YAYIN ETİK
# KURULU YÖNERGESİ.txt
# Ingesting pdfs/engelsiz_yasam.pdf...
# ⠹ Processing pdfs/engelsiz_yasam.pdf...
#  Text successfully extracted to dataset/output/engelsiz_yasam.txt
# Ingesting pdfs/staj_yonergesi.pdf...
# ⠸ Processing pdfs/staj_yonergesi.pdf...
#  Text successfully extracted to dataset/output/staj_yonergesi.txt
# Ingesting pdfs/bologna.pdf...
# ⠧ Processing pdfs/bologna.pdf...
#  Text successfully extracted to dataset/output/bologna.txt
# Ingesting pdfs/is_sagligi.pdf...
# ⠏ Processing pdfs/is_sagligi.pdf...
#  Text successfully extracted to dataset/output/is_sagligi.txt
# Ingesting pdfs/tip_fakulte_olaganustu.pdf...
# ⠼ Processing pdfs/tip_fakulte_olaganustu.pdf...
#  Text successfully extracted to dataset/output/tip_fakulte_olaganustu.txt
# Ingesting pdfs/master_yonerge.pdf...
# ⠦ Processing pdfs/master_yonerge.pdf...
#  Text successfully extracted to dataset/output/master_yonerge.txt
# Ingesting pdfs/onlisans_lisans_azami_sure.pdf...
# ⠸ Processing pdfs/onlisans_lisans_azami_sure.pdf...
#  Text successfully extracted to dataset/output/onlisans_lisans_azami_sure.txt
# Ingesting pdfs/yok.pdf...
# ⠸ Processing pdfs/yok.pdf...
#  Text successfully extracted to dataset/output/yok.txt
# Ingesting pdfs/int_komisyon.pdf...
# ⠸ Processing pdfs/int_komisyon.pdf...
#  Text successfully extracted to dataset/output/int_komisyon.txt
# Ingesting pdfs/pedagojik.pdf...
# ⠸ Processing pdfs/pedagojik.pdf...
#  Text successfully extracted to dataset/output/pedagojik.txt
# Ingesting pdfs/mufredat.pdf...
# ⠹ Processing pdfs/mufredat.pdf...
#  Text successfully extracted to dataset/output/mufredat.txt
# Ingesting pdfs/su_yonetimi.pdf...
# ⠹ Processing pdfs/su_yonetimi.pdf...
#  Text successfully extracted to dataset/output/su_yonetimi.txt
# Ingesting pdfs/master_best_tez.pdf...
# ⠦ Processing pdfs/master_best_tez.pdf...
#  Text successfully extracted to dataset/output/master_best_tez.txt
# Ingesting pdfs/ebelge_yonetim.pdf...
# ⠹ Processing pdfs/ebelge_yonetim.pdf...
#  Text successfully extracted to dataset/output/ebelge_yonetim.txt
# Ingesting pdfs/docent_esozlu.pdf...
# ⠙ Processing pdfs/docent_esozlu.pdf...
#  Text successfully extracted to dataset/output/docent_esozlu.txt
# Ingesting pdfs/iktisadi_isletme.pdf...
# ⠧ Processing pdfs/iktisadi_isletme.pdf...
#  Text successfully extracted to dataset/output/iktisadi_isletme.txt
# Ingesting pdfs/etik_kurul.pdf...
# ⠙ Processing pdfs/etik_kurul.pdf...
#  Text successfully extracted to dataset/output/etik_kurul.txt
# Ingesting pdfs/toplumsal_katki,.pdf...
# ⠧ Processing pdfs/toplumsal_katki,.pdf...
#  Text successfully extracted to dataset/output/toplumsal_katki,.txt
# Ingesting pdfs/ortak_ders.pdf...
# ⠙ Processing pdfs/ortak_ders.pdf...
#  Text successfully extracted to dataset/output/ortak_ders.txt
# Ingesting pdfs/tip_kurallar.pdf...
# ⠴ Processing pdfs/tip_kurallar.pdf...
#  Text successfully extracted to dataset/output/tip_kurallar.txt
# Ingesting pdfs/dumansız_hava_sahasi.pdf...
# ⠙ Processing pdfs/dumansız_hava_sahasi.pdf...
#  Text successfully extracted to dataset/output/dumansız_hava_sahasi.txt
# Ingesting pdfs/bilim_iletisimi.pdf...
# ⠼ Processing pdfs/bilim_iletisimi.pdf...
#  Text successfully extracted to dataset/output/bilim_iletisimi.txt
# Ingesting pdfs/bilimsel_dergiler.pdf...
# ⠸ Processing pdfs/bilimsel_dergiler.pdf...
#  Text successfully extracted to dataset/output/bilimsel_dergiler.txt
# Ingesting pdfs/master_uzmanlik_alan.pdf...
# ⠹ Processing pdfs/master_uzmanlik_alan.pdf...
#  Text successfully extracted to dataset/output/master_uzmanlik_alan.txt
# Ingesting pdfs/uluslararasi_ogr_ofisi.pdf...
# ⠋ Processing pdfs/uluslararasi_ogr_ofisi.pdf...
#  Text successfully extracted to dataset/output/uluslararasi_ogr_ofisi.txt
# Ingesting pdfs/danismanlik.pdf...
# ⠋ Processing pdfs/danismanlik.pdf...
#  Text successfully extracted to dataset/output/danismanlik.txt
# Ingesting pdfs/dijital_donusum.pdf...
# ⠦ Processing pdfs/dijital_donusum.pdf...
#  Text successfully extracted to dataset/output/dijital_donusum.txt
# Ingesting pdfs/atik_yonetimi.pdf...
# ⠸ Processing pdfs/atik_yonetimi.pdf...
#  Text successfully extracted to dataset/output/atik_yonetimi.txt
# Ingesting pdfs/international_danisma.pdf...
# ⠹ Processing pdfs/international_danisma.pdf...
#  Text successfully extracted to dataset/output/international_danisma.txt
# Ingesting pdfs/birim_eklenti_isim.pdf...
# ⠋ Processing pdfs/birim_eklenti_isim.pdf...
#  Text successfully extracted to dataset/output/birim_eklenti_isim.txt
# Ingesting pdfs/azami_sure.pdf...
# ⠙ Processing pdfs/azami_sure.pdf...
#  Text successfully extracted to dataset/output/azami_sure.txt
# Ingesting pdfs/ic_kontrol.pdf...
# ⠸ Processing pdfs/ic_kontrol.pdf...
#  Text successfully extracted to dataset/output/ic_kontrol.txt
# Ingesting pdfs/cift_anadal.pdf...
# ⠼ Processing pdfs/cift_anadal.pdf...
#  Text successfully extracted to dataset/output/cift_anadal.txt
# Ingesting pdfs/senato_esaslari.pdf...
# ⠏ Processing pdfs/senato_esaslari.pdf...
#  Text successfully extracted to dataset/output/senato_esaslari.txt
# Ingesting pdfs/egitim_komisyon.pdf...
# ⠹ Processing pdfs/egitim_komisyon.pdf...
#  Text successfully extracted to dataset/output/egitim_komisyon.txt
# Ingesting pdfs/after_phd.pdf...
# ⠙ Processing pdfs/after_phd.pdf...
#  Text successfully extracted to dataset/output/after_phd.txt
# Ingesting pdfs/tasinir_mal_hurda.pdf...
# ⠋ Processing pdfs/tasinir_mal_hurda.pdf...
#  Text successfully extracted to dataset/output/tasinir_mal_hurda.txt
# Ingesting pdfs/orhun_degisim_prog.pdf...
# ⠧ Processing pdfs/orhun_degisim_prog.pdf...
#  Text successfully extracted to dataset/output/orhun_degisim_prog.txt
# Ingesting pdfs/kvkk.pdf...
# ⠏ Processing pdfs/kvkk.pdf...
#  Text successfully extracted to dataset/output/kvkk.txt
# Ingesting pdfs/bitirme_projesi.pdf...
# ⠼ Processing pdfs/bitirme_projesi.pdf...
#  Text successfully extracted to dataset/output/bitirme_projesi.txt
# Ingesting pdfs/binalarin_yangindan_korunması.pdf...
# ⠇ Processing pdfs/binalarin_yangindan_korunması.pdf...
#  Text successfully extracted to dataset/output/binalarin_yangindan_korunması.txt
# Ingesting pdfs/surekli_egitim_merkezi.pdf...
# ⠹ Processing pdfs/surekli_egitim_merkezi.pdf...
#  Text successfully extracted to dataset/output/surekli_egitim_merkezi.txt
# Ingesting pdfs/bilimsel_arastirma_etik.pdf...
# ⠼ Processing pdfs/bilimsel_arastirma_etik.pdf...
#  Text successfully extracted to dataset/output/bilimsel_arastirma_etik.txt
# Ingesting pdfs/guz_bahar_basvuru.pdf...
# ⠴ Processing pdfs/guz_bahar_basvuru.pdf...
#  Text successfully extracted to dataset/output/guz_bahar_basvuru.txt
# Ingesting pdfs/turkce_ogretimi.pdf...
# ⠹ Processing pdfs/turkce_ogretimi.pdf...
#  Text successfully extracted to dataset/output/turkce_ogretimi.txt
# Ingesting pdfs/disiliskilker.pdf...
# ⠹ Processing pdfs/disiliskilker.pdf...
#  Text successfully extracted to dataset/output/disiliskilker.txt
# Ingesting pdfs/lisans_pedagoji.pdf...
# ⠼ Processing pdfs/lisans_pedagoji.pdf...
#  Text successfully extracted to dataset/output/lisans_pedagoji.txt
# Ingesting pdfs/intibak.pdf...
# ⠸ Processing pdfs/intibak.pdf...
#  Text successfully extracted to dataset/output/intibak.txt
# Ingesting pdfs/Uluslararası (Yabancı uyruklu) Ogrenci Yonergesi 28.02.2016.pdf...
# ⠋ Processing pdfs/Uluslararası (Yabancı uyruklu) Ogrenci Yonergesi
# ⠙ Processing pdfs/Uluslararası (Yabancı uyruklu) Ogrenci Yonergesi
# ⠹ Processing pdfs/Uluslararası (Yabancı uyruklu) Ogrenci Yonergesi
# ⠹ Processing pdfs/Uluslararası (Yabancı uyruklu) Ogrenci Yonergesi
# 28.02.2016.pdf...
#  Text successfully extracted to dataset/output/Uluslararası (Yabancı uyruklu)
# Ogrenci Yonergesi 28.02.2016.txt
# Ingesting pdfs/kultur_spor.pdf...
# ⠼ Processing pdfs/kultur_spor.pdf...
#  Text successfully extracted to dataset/output/kultur_spor.txt
# Ingesting pdfs/bilimsel_dergiler_koordinatorlugu.pdf...
# ⠋ Processing pdfs/bilimsel_dergiler_koordinatorlugu.pdf...
#  Text successfully extracted to
# dataset/output/bilimsel_dergiler_koordinatorlugu.txt
# Ingesting pdfs/int_ogrenci.pdf...
# ⠼ Processing pdfs/int_ogrenci.pdf...
#  Text successfully extracted to dataset/output/int_ogrenci.txt
# Ingesting pdfs/ozel_ogrenci.pdf...
# ⠴ Processing pdfs/ozel_ogrenci.pdf...
#  Text successfully extracted to dataset/output/ozel_ogrenci.txt
# Ingesting pdfs/edys.pdf...
# ⠼ Processing pdfs/edys.pdf...
#  Text successfully extracted to dataset/output/edys.txt
# Ingesting pdfs/enerji_yonetimi.pdf...
# ⠸ Processing pdfs/enerji_yonetimi.pdf...
#  Text successfully extracted to dataset/output/enerji_yonetimi.txt
# Ingesting pdfs/master_egitim_ogretim.pdf...
# ⠧ Processing pdfs/master_egitim_ogretim.pdf...
#  Text successfully extracted to dataset/output/master_egitim_ogretim.txt
# Ingesting pdfs/tip_ogrenci_danismanlik.pdf...
# ⠙ Processing pdfs/tip_ogrenci_danismanlik.pdf...
#  Text successfully extracted to dataset/output/tip_ogrenci_danismanlik.txt
# Ingesting pdfs/Erasmus Yönergesi.pdf...
# ⠏ Processing pdfs/Erasmus Yönergesi.pdf...
#  Text successfully extracted to dataset/output/Erasmus Yönergesi.txt
# Ingesting pdfs/danisma_kurul.pdf...
# ⠦ Processing pdfs/danisma_kurul.pdf...
#  Text successfully extracted to dataset/output/danisma_kurul.txt
# Ingesting pdfs/Ceza sorusturmasi.pdf...
# ⠹ Processing pdfs/Ceza sorusturmasi.pdf...
#  Text successfully extracted to dataset/output/Ceza sorusturmasi.txt
# Ingesting pdfs/ogr_senatosu.pdf...
# ⠸ Processing pdfs/ogr_senatosu.pdf...
#  Text successfully extracted to dataset/output/ogr_senatosu.txt
# Ingesting pdfs/disiplinleraraasi_master.pdf...
# ⠹ Processing pdfs/disiplinleraraasi_master.pdf...
#  Text successfully extracted to dataset/output/disiplinleraraasi_master.txt
# Ingesting pdfs/kalite_guvence.pdf...
# ⠦ Processing pdfs/kalite_guvence.pdf...
#  Text successfully extracted to dataset/output/kalite_guvence.txt
# Ingesting pdfs/yonetmelik.pdf...
# ⠏ Processing pdfs/yonetmelik.pdf...
#  Text successfully extracted to dataset/output/yonetmelik.txt
# Ingesting pdfs/sosyal_secmeli.pdf...
# ⠋ Processing pdfs/sosyal_secmeli.pdf...
#  Text successfully extracted to dataset/output/sosyal_secmeli.txt
# Ingesting pdfs/master_internat.pdf...
# ⠴ Processing pdfs/master_internat.pdf...
#  Text successfully extracted to dataset/output/master_internat.txt
# Ingesting pdfs/sahipsiz_hayvanlar.pdf...
# ⠹ Processing pdfs/sahipsiz_hayvanlar.pdf...
#  Text successfully extracted to dataset/output/sahipsiz_hayvanlar.txt
# Ingesting pdfs/ogr_temsilci.pdf...
# ⠴ Processing pdfs/ogr_temsilci.pdf...
#  Text successfully extracted to dataset/output/ogr_temsilci.txt
# Ingesting pdfs/Uluslararası Ortak Lisans Programları (UOLP) Yönetmeliği.pdf...
# ⠋ Processing pdfs/Uluslararası Ortak Lisans Programları (UOLP)
# ⠙ Processing pdfs/Uluslararası Ortak Lisans Programları (UOLP)
# ⠹ Processing pdfs/Uluslararası Ortak Lisans Programları (UOLP)
# ⠸ Processing pdfs/Uluslararası Ortak Lisans Programları (UOLP)
# Yönetmeliği.pdf...
#  Text successfully extracted to dataset/output/Uluslararası Ortak Lisans
# Programları (UOLP) Yönetmeliği.txt
# Ingesting pdfs/akts.pdf...
# ⠏ Processing pdfs/akts.pdf...
#  Text successfully extracted to dataset/output/akts.txt
# Ingesting pdfs/hakli_gecerli_nedenler.pdf...
# ⠦ Processing pdfs/hakli_gecerli_nedenler.pdf...
#  Text successfully extracted to dataset/output/hakli_gecerli_nedenler.txt
# Ingesting pdfs/yatay_gecis.pdf...
# ⠇ Processing pdfs/yatay_gecis.pdf...
#  Text successfully extracted to dataset/output/yatay_gecis.txt
# Ingesting pdfs/Hayvan Deneyleri Etik Kurulu Yönergesi.pdf...
# ⠴ Processing pdfs/Hayvan Deneyleri Etik Kurulu Yönergesi.pdf...
#  Text successfully extracted to dataset/output/Hayvan Deneyleri Etik Kurulu
# Yönergesi.txt
# Ingesting pdfs/veteriner_hayvan_hastane.pdf...
# ⠋ Processing pdfs/veteriner_hayvan_hastane.pdf...
#  Text successfully extracted to dataset/output/veteriner_hayvan_hastane.txt
# Ingesting pdfs/kurumsal_iletisim.pdf...
# ⠸ Processing pdfs/kurumsal_iletisim.pdf...
#  Text successfully extracted to dataset/output/kurumsal_iletisim.txt
# Ingesting pdfs/kurumsal_risk.pdf...
# ⠴ Processing pdfs/kurumsal_risk.pdf...
#  Text successfully extracted to dataset/output/kurumsal_risk.txt
# Ingesting pdfs/on_mali_kontrol.pdf...
# ⠧ Processing pdfs/on_mali_kontrol.pdf...
#  Text successfully extracted to dataset/output/on_mali_kontrol.txt
# Ingesting pdfs/ders_ucret.pdf...
# ⠹ Processing pdfs/ders_ucret.pdf...
#  Text successfully extracted to dataset/output/ders_ucret.txt
# Ingesting pdfs/sertifika_belge.pdf...
# ⠴ Processing pdfs/sertifika_belge.pdf...
#  Text successfully extracted to dataset/output/sertifika_belge.txt
# total 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipython-input-432101761.py in <cell line: 0>()
#      21
#      22 # Truncate document
# ---> 23 filenames = generator.chunk_data("dataset/output/*.txt")
#      24 print(len(filenames), filenames[:3])
#
# /usr/local/lib/python3.11/dist-packages/unsloth/dataprep/synthetic.py in chunk_data(self, filename)
#     224         # Chunks data by max tokens and generation length
#     225         assert(filename is not None)
# --> 226         assert(os.path.exists(filename))
#     227         assert(hasattr(self, "tokenizer"))
#     228         if not hasattr(self, "max_seq_length"):
#
# AssertionError:

# %% [markdown]
# We see around 37 chunks of data. We now call synthetic-data-kit to create some pairs of data for 3 of our chunks.
#
# You can process more chunks, but it'll be much slower!
#
# Using `--num-pairs` will generate **approximately** that many QA pairs. However it might be shorter or longer depending on the `max_seq_length` of the loaded up model. So if you specify 100, you might only get 10 since the model's max sequence length is capped.

# %%
import glob

filenames = glob.glob("dataset/output/*.txt")

print(f"Found {len(filenames)} files in dataset/output/")
print(filenames[:3])
# Out:
# Found 83 files in dataset/output/
# ['dataset/output/bilim_iletisimi.txt', 'dataset/output/sertifika_belge.txt', 'dataset/output/ogr_senatosu.txt']

# %%
import time
# Process 3 chunks for now -> can increase but slower!
for filename in filenames[:3]:
    # !synthetic-data-kit \
        -c synthetic_data_kit_config.yaml \
        create {filename} \
        --num-pairs 25 \
        --type "qa"
    time.sleep(2) # Sleep some time to leave some room for processing
# Out:
# ⠏ Generating qa content from dataset/output/bilim_iletisimi.txt...
# L Error: Failed to get completion after 3 attempts: 400 Client Error: Bad
# Request for url: http://localhost:8000/v1/chat/completions
# ⠇ Generating qa content from dataset/output/sertifika_belge.txt...
# L Error: Failed to get completion after 3 attempts: 400 Client Error: Bad
# Request for url: http://localhost:8000/v1/chat/completions
# ⠧ Generating qa content from dataset/output/ogr_senatosu.txt...
# L Error: Failed to get completion after 3 attempts: 400 Client Error: Bad
# Request for url: http://localhost:8000/v1/chat/completions

# %% [markdown]
# Optionally, you can clean up the data via pruning "bad" or low quality examples and convert the rest to JSON format for finetuning!

# %%
# !synthetic-data-kit \
#     -c synthetic_data_kit_config.yaml \
#     curate --threshold 0.0 \
#     "data/generated/arxiv_org_0_qa_pairs.json"

# %% [markdown]
# We now convert the generated datasets into QA formats so we can load it for finetuning:

# %%
qa_pairs_filenames = [
    f"data/generated/arxiv_org_{i}_qa_pairs.json"
    for i in range(len(filenames[:3]))
]
for filename in qa_pairs_filenames:
    # !synthetic-data-kit \
        -c synthetic_data_kit_config.yaml \
        save-as {filename} -f ft
# Out:
# ⠋ Converting data/generated/arxiv_org_0_qa_pairs.json to ft format with json
# storage...
#  Converted to ft format and saved to data/final/arxiv_org_0_qa_pairs_ft.json
# ⠋ Converting data/generated/arxiv_org_1_qa_pairs.json to ft format with json
# storage...
#  Converted to ft format and saved to data/final/arxiv_org_1_qa_pairs_ft.json
# ⠋ Converting data/generated/arxiv_org_2_qa_pairs.json to ft format with json
# storage...
#  Converted to ft format and saved to data/final/arxiv_org_2_qa_pairs_ft.json

# %% [markdown]
# Let's load up the data and see what the synthetic data looks like!

# %%
from datasets import Dataset
import pandas as pd
final_filenames = [
    f"data/final/arxiv_org_{i}_qa_pairs_ft.json"
    for i in range(len(filenames[:3]))
]
conversations = pd.concat([
    pd.read_json(name) for name in final_filenames
]).reset_index(drop = True)

dataset = Dataset.from_pandas(conversations)

# %%
dataset[0]
# Out:
# {'messages': [{'content': 'You are a helpful assistant.', 'role': 'system'},
#   {'content': 'What is the primary unit of computation in the Byte Latent Transformer (BLT) architecture?',
#    'role': 'user'},
#   {'content': 'Patches', 'role': 'assistant'}]}

# %%
dataset[1]
# Out:
# {'messages': [{'content': 'You are a helpful assistant.', 'role': 'system'},
#   {'content': 'How do patches in BLT architecture get segmented?',
#    'role': 'user'},
#   {'content': 'Based on the entropy of the next byte', 'role': 'assistant'}]}

# %%
dataset[-1]
# Out:
# {'messages': [{'content': 'You are a helpful assistant.', 'role': 'system'},
#   {'content': 'What is the main purpose of the formal definition of the patching function?',
#    'role': 'user'},
#   {'content': 'to formally describe the process of segmenting bytes into patches',
#    'role': 'assistant'}]}

# %% [markdown]
# Finally free vLLM process to save memory and to allow for finetuning!

# %%
generator.cleanup()
# Out:
# Attempting to terminate the VLLM server gracefully...
# Server terminated gracefully.

# %% [markdown]
# ### Fine-tuning Synthetic Dataset with Unsloth

# %%
from unsloth import FastLanguageModel
import torch

fourbit_models = [
    # 4bit dynamic quants for superior accuracy and low memory use
    "unsloth/gemma-3-4b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-12b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-27b-it-unsloth-bnb-4bit",
    # Qwen3 new models
    "unsloth/Qwen3-4B-unsloth-bnb-4bit",
    "unsloth/Qwen3-8B-unsloth-bnb-4bit",
    # Other very popular models!
    "unsloth/Llama-3.1-8B",
    "unsloth/Llama-3.2-3B",
    "unsloth/Llama-3.3-70B",
    "unsloth/mistral-7b-instruct-v0.3",
    "unsloth/Phi-4",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-3B-Instruct",
    max_seq_length = 2048, # Choose any for long context!
    load_in_4bit = True,  # 4 bit quantization to reduce memory
    load_in_8bit = False, # [NEW!] A bit more accurate, uses 2x memory
    full_finetuning = False, # [NEW!] We have full finetuning now!
    # token = "hf_...", # use one if using gated models
)
# Out:
# ==((====))==  Unsloth 2025.4.3: Fast Llama patching. Transformers: 4.51.3. vLLM: 0.8.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.35G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/54.7k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2025.4.3 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the `Llama-3.2` format for conversation style finetunes. The chat template renders conversations like below: (Cutting Knowledge Date is by default there!)
#
# ```
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 01 May 2025
#
# You are a helpful assistant.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# What is 1+1?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# 2<|eot_id|>
# ```

# %%
def formatting_prompts_func(examples):
    convos = examples["messages"]
    texts = [tokenizer.apply_chat_template(convo, tokenize = False, add_generation_prompt = False) for convo in convos]
    return { "text" : texts, }
pass

# Get our previous dataset and format it:
dataset = dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Map:   0%|          | 0/35 [00:00<?, ? examples/s]

# %% [markdown]
# See result of the first row:

# %%
dataset[0]
# Out:
# {'messages': [{'content': 'You are a helpful assistant.', 'role': 'system'},
#   {'content': 'What is the primary unit of computation in the Byte Latent Transformer (BLT) architecture?',
#    'role': 'user'},
#   {'content': 'Patches', 'role': 'assistant'}],
#  'text': '<|begin_of_text|><|start_header_id|>system<|end_header_id|>\n\nCutting Knowledge Date: December 2023\nToday Date: 01 May 2025\n\nYou are a helpful assistant.<|eot_id|><|start_header_id|>user<|end_header_id|>\n\nWhat is the primary unit of computation in the Byte Latent Transformer (BLT) architecture?<|eot_id|><|start_header_id|>assistant<|end_header_id|>\n\nPatches<|eot_id|>'}

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`.

# %%
from trl import SFTTrainer, SFTConfig

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    eval_dataset = None, # Can set up evaluation!
    args = SFTConfig(
        dataset_text_field = "text",
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4, # Use GA to mimic batch size!
        warmup_steps = 5,
        max_steps = 60,
        learning_rate = 2e-4,
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        report_to = "none", # Use this for WandB etc
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/35 [00:00<?, ? examples/s]

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.741 GB.
# 3.441 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 35 | Num Epochs = 15 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 24,313,856/3,000,000,000 (0.81% trained)
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 01:47, Epoch 12/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.770500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.901100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.770800</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.705000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.940100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.610800</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.617000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.426600</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.255000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.410500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.328100</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.193000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.215000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.027200</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.933600</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.976800</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.928700</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.865900</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.956300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.925800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.853600</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.663600</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.772600</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.609900</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.634200</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.556100</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.489200</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.523400</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.465100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.545400</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.373400</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.358500</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.344900</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.302400</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.400300</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.294800</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.272400</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.264200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.233400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.244500</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.212200</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.192300</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.177500</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.175400</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.176100</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.146400</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.142300</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.133200</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.132700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.147300</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.118800</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.116800</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.106100</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.101200</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.101300</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.096300</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.103200</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.099000</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.107300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.105100</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 110.0157 seconds used for training.
# 1.83 minutes used for training.
# Peak reserved memory = 3.441 GB.
# Peak reserved memory for training = 0.0 GB.
# Peak reserved memory % of max memory = 23.343 %.
# Peak reserved memory for training % of max memory = 0.0 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! Use `apply_chat_template` with `add_generation_prompt` set to `True` for inference.

# %%
messages = [
    {"role": "user", "content": "What is the Byte Latent Transformer?"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(input_ids = inputs, streamer = text_streamer,
                   max_new_tokens = 256, temperature = 0.1)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# A novel architecture that uses patches to encode bytes<|eot_id|>

# %% [markdown]
# The model learns about the research paper!!

# %%
messages = [
    {"role": "user", "content": "What are some benefits of the BLT?"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(input_ids = inputs, streamer = text_streamer,
                   max_new_tokens = 256, temperature = 0.1)
# Out:
# Improved inference capabilities, enhanced model robustness, and the ability to scale while maintaining a fixed-inference budget<|eot_id|>

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model")  # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
messages = [
    {"role": "user", "content": "What is so special about BLT's tokenization?"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(input_ids = inputs, streamer = text_streamer,
                   max_new_tokens = 256, temperature = 0.1)
# Out:
# It dynamically groups bytes into patches preserving access to the byte-level information<|eot_id|>

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False:
    model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: # Change to True to upload finetune
    model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False:
    model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: # Change to True to upload finetune
    model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False:
    model.save_pretrained("model")
    tokenizer.save_pretrained("model")
if False: # Change to True to upload finetune
    model.push_to_hub("hf/model", token = "")
    tokenizer.push_to_hub("hf/model", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
# Save to 8bit Q8_0
if False:
    model.save_pretrained_gguf("model", tokenizer,)
if False: # Change to True to upload finetune
    model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False:
    model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: # Change to True to upload finetune
    model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False:
    model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: # Change to True to upload finetune
    model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp or a UI based system like Jan or Open WebUI. You can install Jan [here](https://github.com/janhq/jan) and Open WebUI [here](https://github.com/open-webui/open-webui)
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>

# %%
# !synthetic-data-kit \
    -c synthetic_data_kit_config.yaml \
    ingest "data/"
# !ls -l data
# !ls -l data/output
# Out:
# ⠋ Processing data/...
# L Error: Unsupported file extension:
# total 40
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 cleaned
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 docx
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 final
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 generated
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 html
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 output
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 pdf
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 ppt
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 txt
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 youtube
# total 0

# %%
# !ls -l
# !ls -l data
# Out:
# total 47704
# drwxr-xr-x 12 root root     4096 Aug 14 11:40 data
# drwxr-xr-x 12 root root     4096 Aug 14 10:32 dataset
# -rw-r--r--  1 root root 48819898 Aug 14 11:33 data.zip
# drwxrwxrwx  3 root root     4096 Aug 14 11:38 pdfs
# drwxr-xr-x  1 root root     4096 Aug 12 13:39 sample_data
# -rw-r--r--  1 root root     3034 Aug 14 11:48 synthetic_data_kit_config.yaml
# drwxr-xr-x  3 root root     4096 Aug 14 10:27 unsloth_compiled_cache
# -rw-r--r--  1 root root     2451 Aug 14 10:23 vllm_requirements.txt
# total 40
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 cleaned
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 docx
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 final
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 generated
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 html
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 output
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 pdf
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 ppt
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 txt
# drwxr-xr-x 2 root root 4096 Aug 14 11:40 youtube
